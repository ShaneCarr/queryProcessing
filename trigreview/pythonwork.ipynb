# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Circle

angle_degrees = 30
# radian is radius wrapped around circle
# 360 degress = 2*pi radians

# conversion factor
# the key is that both radians and derees are a measure of movement around a circle.
# degrees to radians: 360/ 2*pi * radians = 180/ (pi  * radians) --degrees per radian or vice versal
# this simple ratio can be wroked either way to convert from one to the other.
angle_radians = np.radians(angle_degrees)

opposite = np.sin(angle_radians)
adjacent = np.cos(angle_radians)
hypotenuse = 1
plt.figure(figsize=(10, 10), dpi=100)
####plt.figure(figsize=(5, 5))
# plt.plot([x1, x2], [y1, y2], 'k-')
plt.plot([0, adjacent], [0, 0], 'r-', label='Adjacent (cos)')
plt.plot([adjacent, adjacent], [0, opposite], 'b-', label='')
plt.plot([0, adjacent], [0, opposite], 'g--', label='Hypotenuse')

# draw the axis
plt.plot([0, 0], [0, 1], 'k--', alpha=0.3)  # Extend y-axis visually
plt.plot([1, 0], [0, 0], 'k--', alpha=0.3)
plt.plot([0, 0], [0, -1], 'k--', alpha=0.3)
plt.plot([-0, 0], [0, 0], 'k--', alpha=0.3)

# Add labels and legend
plt.text(adjacent / 2, -0.05, 'cos(θ)', horizontalalignment='center')
plt.text(adjacent + 0.05, opposite / 2, 'sin(θ)', verticalalignment='center')
plt.text(adjacent / 2 - 0.1, opposite / 2, 'θ', horizontalalignment='center')
plt.legend(loc='upper right')

circle = Circle((0, 0), 1, fill=False, color='blue', linestyle='-', alpha=0.5)
plt.gca().add_patch(circle)
plt.xlim(-1.1, 1.1)
plt.ylim(-1.1, 1.1)
plt.gca().set_aspect('equal', adjustable='box')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Unit Circle with Trigonometric Functions')
plt.grid(True, which='both')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a range of angles from 0 to 2*pi radians
theta = np.linspace(0, 2 * np.pi, 100)

# Calculate x and y coordinates of points on the circle
x = np.cos(theta)
y = np.sin(theta)

# Plot the circle
plt.figure(figsize=(5, 5))
plt.plot(x, y)
plt.title('Unit Circle')
plt.xlabel('Cosine (x)')
plt.ylabel('Sine (y)')
plt.grid(True)
plt.axis('equal')  # Ensure the aspect ratio is equal to make the circle look round
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate an array of angles from 0 to 2*pi (360 degrees)
angles = np.linspace(0, 2 * np.pi, 400)

# Compute sine and cosine of these angles
sine_wave = np.sin(angles)
cosine_wave = np.cos(angles)

# Plotting sine and cosine waves
plt.figure(figsize=(10, 5))
plt.plot(angles, sine_wave, label='Sine Wave')
plt.plot(angles, cosine_wave, label='Cosine Wave', linestyle='--')

# Adding labels and legend
plt.xlabel('Angle (radians)')
plt.ylabel('Function value')
plt.title('Sine and Cosine Waves')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Define the sides of the triangle
a, b = 3, 4
c = (a**2 + b**2)**0.5  # Hypotenuse, c

# Create the plot
fig, ax = plt.subplots()
ax.set_aspect('equal')
plt.axis('off')

# Calculate positions for the square and triangles
large_square_side = a + b
triangle_height = b  # Same as side b of the triangle
triangle_base = a  # Same as side a of the triangle

# Outer large square (a+b) x (a+b)
outer_square = patches.Rectangle((0, 0), large_square_side, large_square_side, linewidth=2, edgecolor='black', fill=False)
ax.add_patch(outer_square)

# Inner square a^2
square_a = patches.Rectangle((0, b), a, a, linewidth=2, edgecolor='blue', fill=True, alpha=0.5)
ax.add_patch(square_a)

# Inner square b^2
square_b = patches.Rectangle((a, 0), b, b, linewidth=2, edgecolor='green', fill=True, alpha=0.5)
ax.add_patch(square_b)

# Central square c^2, formed by the hypotenuses of the triangles
central_square = patches.Rectangle((a, b), c, c, linewidth=2, edgecolor='red', linestyle='--', fill=False)
ax.add_patch(central_square)

# Add the four right-angled triangles
# Triangle 1
triangle1 = patches.Polygon([(0, b), (a, b), (a, b+a)], fill=True, color='grey', alpha=0.3)
ax.add_patch(triangle1)
# Triangle 2
triangle2 = patches.Polygon([(a, b), (a, b+c), (a+c, b+c)], fill=True, color='grey', alpha=0.3)
ax.add_patch(triangle2)
# Triangle 3
triangle3 = patches.Polygon([(a, b), (a+c, b), (a+c, b+c)], fill=True, color='grey', alpha=0.3)
ax.add_patch(triangle3)
# Triangle 4 (not needed as triangles 2 and 3 complete the square)

# Annotations
plt.text(a/2, b - 0.5, '$a$', ha='center')
plt.text(a + 0.5, b/2, '$b$', va='center', rotation='vertical')
plt.text(a + c/2, b - 0.5, '$c$', ha='center', color='red')
plt.text(a/2, b + a/2, '$a$', ha='center')
plt.text(a + b/2, b/2, '$b$', va='center')

# Adjusting the plot limits
plt.xlim(-1, large_square_side + 1)
plt.ylim(-1, large_square_side + 1)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Define the sides of the triangle
a, b = 3, 4
c = (a**2 + b**2)**0.5  # Hypotenuse, c

# Create the plot
fig, ax = plt.subplots()
ax.set_aspect('equal')
plt.axis('off')

# Calculate positions for the large square
large_square_side = a + b

# Outer large square (a+b) x (a+b)
outer_square = patches.Rectangle((0, 0), large_square_side, large_square_side, linewidth=2, edgecolor='black', fill=False)
ax.add_patch(outer_square)

# Inner square a^2
square_a = patches.Rectangle((b, 0), a, a, linewidth=2, edgecolor='blue', fill=True, alpha=0.5)
ax.add_patch(square_a)

# Inner square b^2
square_b = patches.Rectangle((0, a), b, b, linewidth=2, edgecolor='green', fill=True, alpha=0.5)
ax.add_patch(square_b)

# Central square c^2, formed by the hypotenuses of the triangles
central_square = patches.Rectangle((b, a), c, c, linewidth=2, edgecolor='red', linestyle='--', fill=False)
ax.add_patch(central_square)

# Add the four right-angled triangles
triangles = [
    patches.Polygon([(b, a), (b, a+c), (b+c, a+c)], closed=True, fill=True, color='grey', alpha=0.5),  # Top right
    patches.Polygon([(b, a), (b+c, a), (b+c, a+c)], closed=True, fill=True, color='grey', alpha=0.5),  # Bottom right
    patches.Polygon([(0, a), (b, a), (b, 0)], closed=True, fill=True, color='grey', alpha=0.5),  # Bottom left
    patches.Polygon([(0, a), (0, a+b), (b, a+b)], closed=True, fill=True, color='grey', alpha=0.5),  # Top left
]

for t in triangles:
    ax.add_patch(t)

# Annotations for side lengths
plt.text(b/2, -0.2, 'b', ha='center', fontsize=12)
plt.text(b + a/2, -0.2, 'a', ha='center', fontsize=12)
plt.text(b + a + 0.2, a/2, 'a', va='center', fontsize=12, rotation='vertical')
plt.text(b - 0.2, a/2, 'b', ha='center', fontsize=12, rotation='vertical')
plt.text(b + a + c/2, a + c/2, 'c', color='red')

# Adjusting the plot limits
plt.xlim(-1, large_square_side + 1)
plt.ylim(-1, large_square_side + 1)

# Add a title and a key to the plot
plt.title('Pythagorean Theorem Visual Proof', fontsize=16, y=1.05)
plt.text(large_square_side + 1, large_square_side/2,
         "Key:\n\n"
         "Large outer square side: a + b\n\n"
         "Blue square area: a^2\n\n"
         "Green square area: b^2\n\n"
         "Red dashed square area: c^2\n\n"
         "Grey triangles: 4 right-angled triangles\n\n"
         "Proof:\n"
         "Area of large square = (a+b)^2\n"
         "Area of large square = 2ab + c^2\n"
         "Therefore, a^2 + b^2 = c^2",
         fontsize=12)
# Out:
# Text(8, 3.5, 'Key:\n\nLarge outer square side: a + b\n\nBlue square area: a^2\n\nGreen square area: b^2\n\nRed dashed square area: c^2\n\nGrey triangles: 4 right-angled triangles\n\nProof:\nArea of large square = (a+b)^2\nArea of large square = 2ab + c^2\nTherefore, a^2 + b^2 = c^2')

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Define the triangle sides
a, b = 3, 4
c = (a**2 + b**2)**0.5  # Hypotenuse

# Create the figure and axis
fig, ax = plt.subplots()
ax.set_aspect('equal')
plt.axis('off')

# Outer large square (a+b) x (a+b)
outer_square = patches.Rectangle((0, 0), a+b, a+b, linewidth=2, edgecolor='black', fill=False)
ax.add_patch(outer_square)

# Inner squares for a^2 and b^2, correctly sized and positioned
square_a = patches.Rectangle((0, 0), a, a, linewidth=2, edgecolor='blue', fill=True, alpha=0.5)
square_b = patches.Rectangle((a, a), b, b, linewidth=2, edgecolor='green', fill=True, alpha=0.5)
ax.add_patch(square_a)
ax.add_patch(square_b)

# Central square for c^2, formed by the hypotenuses of the triangles
central_square = patches.Rectangle((a, 0), b, b, linewidth=2, edgecolor='red', linestyle='--', fill=False)
ax.add_patch(central_square)

# Draw the four right-angled triangles
# Triangle at the top left
triangle1 = patches.Polygon([(0, a), (a, a), (0, b+a)], fill=True, color='grey', alpha=0.5)
# Triangle at the top right
triangle2 = patches.Polygon([(a, a+b), (a+b, a+b), (a+b, a)], fill=True, color='grey', alpha=0.5)
# Triangle at the bottom right
triangle3 = patches.Polygon([(a+b, 0), (a+b, a), (a, 0)], fill=True, color='grey', alpha=0.5)
# Triangle at the bottom left
triangle4 = patches.Polygon([(a, 0), (0, 0), (0, a)], fill=True, color='grey', alpha=0.5)

ax.add_patch(triangle1)
ax.add_patch(triangle2)
ax.add_patch(triangle3)
ax.add_patch(triangle4)

# Label the squares and triangles
plt.text(a/2, a/2, '$a^2$', ha='center', va='center', fontsize=12)
plt.text(a+b/2, a+b/2, '$b^2$', ha='center', va='center', fontsize=12)
plt.text(a+b/2, b/2, '$c^2$', ha='center', va='center', fontsize=12, color='red')

# Set the limits of the plot
plt.xlim(-1, 2*(a+b))
plt.ylim(-1, 2*(a+b))

plt.show()

# %%
import matplotlib.pyplot as plt

# Data setup
time_points = ['Current', 'Teams Storyline Release', 'After 10% Growth']
users_table_records = [665115216, 935920549, 1029512604]  # Users table record count over the three points
messages_table_records = [1562916598, 1719208258, 1891128084]  # Messages table record count over the three points

# Server load IO for HDB and Messages servers
hdb_io_load = [825925.485, 908518.034, 999369.837]  # Original IO load on HDB server
messages_io_load = [1305478.38, 1436026.218, 1579628.84]  # Original IO load on Messages server
new_hdb_io_load = [1319168.185, 1451085.003, 1596193.503]  # New IO load on HDB server
new_messages_io_load = [1377591.724, 1555812.854, 1737591.724]  # New IO load on Messages server

# Plotting Operation Count for Users and Messages tables
plt.figure(figsize=(14, 7))
plt.plot(time_points, users_table_records, 'g-', label='Users Table Records', marker='o')
plt.plot(time_points, messages_table_records, 'r-', label='Messages Table Records', marker='o')

# Annotating the data points
for i, txt in enumerate(users_table_records):
    plt.annotate(txt, (time_points[i], users_table_records[i]), textcoords="offset points", xytext=(0,10), ha='center', color='green')
for i, txt in enumerate(messages_table_records):
    plt.annotate(txt, (time_points[i], messages_table_records[i]), textcoords="offset points", xytext=(0,10), ha='center', color='red')

plt.title('Record Count Over Time for Users and Messages Tables')
plt.xlabel('Time Point')
plt.ylabel('Record Count')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting IO Load for HDB and Messages servers
plt.figure(figsize=(14, 7))
plt.plot(time_points, hdb_io_load, 'g--', label='HDB Server IO Load', marker='o')
plt.plot(time_points, messages_io_load, 'r--', label='Messages Server IO Load', marker='o')
plt.plot(time_points, new_hdb_io_load, 'b-.', label='New HDB Server IO Load', marker='o', linewidth=2)
plt.plot(time_points, new_messages_io_load, 'm-.', label='New Messages Server IO Load', marker='o', linewidth=2)

# Annotating the data points for IO load
for i, txt in enumerate(hdb_io_load):
    plt.annotate(f"{txt:.2f}", (time_points[i], hdb_io_load[i]), textcoords="offset points", xytext=(0,10), ha='center', color='green')
for i, txt in enumerate(messages_io_load):
    plt.annotate(f"{txt:.2f}", (time_points[i], messages_io_load[i]), textcoords="offset points", xytext=(0,10), ha='center', color='red')
for i, txt in enumerate(new_hdb_io_load):
    plt.annotate(f"{txt:.2f}", (time_points[i], new_hdb_io_load[i]), textcoords="offset points", xytext=(0,10), ha='center', color='blue')
for i, txt in enumerate(new_messages_io_load):
    plt.annotate(f"{txt:.2f}", (time_points[i], new_messages_io_load[i]), textcoords="offset points", xytext=(0,10), ha='center', color='magenta')

plt.title('Server IO Load Over Time')
plt.xlabel('Time Point')
plt.ylabel('IO Load')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data setup
time_points = ['Current', 'Teams Storyline Release', 'After 10% Growth']
users_table_records = [665115216, 935920549, 1029512604]  # Users table record count over the three points
messages_table_records = [1562916598, 1719208258, 1891128084]  # Messages table record count over the three points

# Server load IO for HDB and Messages servers
hdb_io_load = [825925.485, 908518.034, 999369.837]  # Original IO load on HDB server
messages_io_load = [1305478.38, 1436026.218, 1579628.84]  # Original IO load on Messages server
new_hdb_io_load = [1319168.185, 1451085.003, 1596193.503]  # New IO load on HDB server
new_messages_io_load = [1377591.724, 1555812.854, 1737591.724]  # New IO load on Messages server

# Plotting Operation Count for Users and Messages tables
plt.figure(figsize=(14, 7))
plt.plot(time_points, users_table_records, 'g-', label='Users Table Records', marker='o')
plt.plot(time_points, messages_table_records, 'r-', label='Messages Table Records', marker='o')

# Annotating the data points
for i, txt in enumerate(users_table_records):
    plt.annotate(txt, (time_points[i], users_table_records[i]), textcoords="offset points", xytext=(0,10), ha='center', color='green')
for i, txt in enumerate(messages_table_records):
    plt.annotate(txt, (time_points[i], messages_table_records[i]), textcoords="offset points", xytext=(0,10), ha='center', color='red')

plt.title('Record Count Over Time for Users and Messages Tables')
plt.xlabel('Time Point')
plt.ylabel('Record Count')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Plotting IO Load for HDB and Messages servers separately
plt.figure(figsize=(14, 7))
plt.plot(time_points, hdb_io_load, 'g--', label='HDB Server IO Load', marker='o')
plt.plot(time_points, messages_io_load, 'r--', label='Messages Server IO Load', marker='o')
plt.plot(time_points, new_hdb_io_load, 'b-.', label='New HDB Server IO Load', marker='o', linewidth=2)
plt.plot(time_points, new_messages_io_load, 'm-.', label='New Messages Server IO Load', marker='o', linewidth=2)

# Annotating the data points for IO load
for i, txt in enumerate(hdb_io_load):
    plt.annotate(f"{txt:.2f}", (time_points[i], hdb_io_load[i]), textcoords="offset points", xytext=(0,10), ha='center', color='green')
for i, txt in enumerate(messages_io_load):
    plt.annotate(f"{txt:.2f}", (time_points[i], messages_io_load[i]), textcoords="offset points", xytext=(0,10), ha='center', color='red')
for i, txt in enumerate(new_hdb_io_load):
    plt.annotate(f"{txt:.2f}", (time_points[i], new_hdb_io_load[i]), textcoords="offset points", xytext=(0,10), ha='center', color='blue')
for i, txt in enumerate(new_messages_io_load):
    plt.annotate(f"{txt:.2f}", (time_points[i], new_messages_io_load[i]), textcoords="offset points", xytext=(0,10), ha='center', color='magenta')

plt.title('Server IO Load Over Time')
plt.xlabel('Time Point')
plt.ylabel('IO Load')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Recalculating the new users added for Teams storyline release
original_active_users = 256606268
percentage_of_licensed_users_from_native_mode = 0.66
teams_engage_intersected_users = 935920549

# Calculate new users added for Teams storyline
new_users_added = teams_engage_intersected_users - (original_active_users * percentage_of_licensed_users_from_native_mode)
# Calculate total users after adding new users to original count
total_users_storyline_release = 665115216 + new_users_added

# Data setup with corrected values
time_points = ['Current', 'Teams Storyline Release', 'After 10% Growth']
users_table_records = [665115216, total_users_storyline_release, total_users_storyline_release * 1.1]  # Adjusted for new calculation

# IO Load scaling based on user count increase
# Current IO loads
hdb_io_load_current = 825925.485
messages_io_load_current = 1305478.38

# Scale IO loads based on user increase
hdb_io_load_scaled = hdb_io_load_current * (total_users_storyline_release / 665115216)
messages_io_load_scaled = messages_io_load_current * 1.1  # Assuming a 10% increase for messages

hdb_io_load = [hdb_io_load_current, hdb_io_load_scaled, hdb_io_load_scaled * 1.1]
messages_io_load = [messages_io_load_current, messages_io_load_scaled, messages_io_load_scaled * 1.1]

# Plotting Operation Count for Users and Messages tables
plt.figure(figsize=(14, 7))
plt.plot(time_points, users_table_records, 'g-', label='Users Table Records', marker='o')
plt.plot(time_points, messages_table_records, 'r-', label='Messages Table Records', marker='o')

# Annotating the data points
for i, txt in enumerate(users_table_records):
    plt.annotate(f"{txt:.0f}", (time_points[i], users_table_records[i]), textcoords="offset points", xytext=(0,10), ha='center', color='green')
for i, txt in enumerate(messages_table_records):
    plt.annotate(f"{txt:.0f}", (time_points[i], messages_table_records[i]), textcoords="offset points", xytext=(0,10), ha='center', color='red')

plt.title('Record Count Over Time for Users and Messages Tables')
plt.xlabel('Time Point')
plt.ylabel('Record Count')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting IO Load for HDB and Messages servers
plt.figure(figsize=(14, 7))
plt.plot(time_points, hdb_io_load, 'g--', label='HDB Server IO Load', marker='o')
plt.plot(time_points, messages_io_load, 'r--', label='Messages Server IO Load', marker='o')

# Annotating the data points for IO load
for i, txt in enumerate(hdb_io_load):
    plt.annotate(f"{txt:.2f}", (time_points[i], hdb_io_load[i]), textcoords="offset points", xytext=(0,10), ha='center', color='green')
for i, txt in enumerate(messages_io_load):
    plt.annotate(f"{txt:.2f}", (time_points[i], messages_io_load[i]), textcoords="offset points", xytext=(0,10), ha='center', color='red')

plt.title('Server IO Load Over Time')
plt.xlabel('Time Point')
plt.ylabel('IO Load')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Preparing data for the table
growth_rate_users_storyline = (total_users_storyline_release - 665115216) / 665115216
growth_rate_users_final = 1.1  # 10% growth after Teams Storyline Release

# Store these for table generation
users_storyline_release_percentage = growth_rate_users_storyline * 100
final_growth_percentage = growth_rate_users_final * 100

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    "day": [
        "2024-02-21", "2024-02-20", "2024-02-20", "2024-02-19", "2024-02-19",
        "2024-02-18", "2024-02-18", "2024-02-17", "2024-02-17", "2024-02-16",
        "2024-02-16", "2024-02-15", "2024-02-15", "2024-02-14", "2024-02-14"
    ],
    "table": [
        "users", "messages", "users", "messages", "users",
        "messages", "users", "users", "messages", "messages",
        "users", "users", "messages", "messages", "users"
    ],
    "TotalHighImpactValue": [
        6128814194901, 97439606342100.0, 153186811267947.0, 97389495205014.0, 104138394902569.0,
        97339993739146.0, 110244843171442.0, 220468632256357.0, 97307903344847.0, 97262815437860.0,
        183596131855785.0, 36702977203678.0, 97229339529514.0, 8101056055471, 110087909186747.0
    ]
}

df = pd.DataFrame(data)
df['day'] = pd.to_datetime(df['day'])  # Convert 'day' to datetime
df.sort_values(by='day', inplace=True)  # Sort by day for chronological plotting

# Plot settings
plt.figure(figsize=(14, 8))
colors = {"users": "green", "messages": "red"}  # Color assignments for each table

for table in df['table'].unique():
    table_df = df[df['table'] == table]
    plt.plot(table_df['day'], table_df['TotalHighImpactValue'], marker='o', label=table, color=colors[table])
    for i, point in table_df.iterrows():
        plt.text(point['day'], point['TotalHighImpactValue'], f"{point['TotalHighImpactValue']:,.0f}", 
                 fontsize=8, rotation=45, ha='right', va='bottom', color=colors[table])

plt.title("IO Load Comparison: Users vs Messages tables")
plt.xlabel("Day")
plt.ylabel("Total High Impact IO Value")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
# Out:
# /var/folders/j5/0k6z25bx10j13546ttz4y1f40000gn/T/ipykernel_81109/427159447.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Given data for comparison of servers "hdb" and "messages"
server_data = {
    "day": [
        "2024-02-21", "2024-02-21", "2024-02-20", "2024-02-20",
        "2024-02-19", "2024-02-19", "2024-02-18", "2024-02-18",
        "2024-02-17", "2024-02-17", "2024-02-16", "2024-02-16",
        "2024-02-15", "2024-02-15", "2024-02-14", "2024-02-14"
    ],
    "dbserver": [
        "messages", "hdb", "messages", "hdb",
        "messages", "hdb", "messages", "hdb",
        "hdb", "messages", "hdb", "messages",
        "messages", "hdb", "hdb", "messages"
    ],
    "TotalHighImpactValue": [
        140339871260, 908974065862, 1680676100925, 11351146323491.0,
        1675746440930, 7707565832986, 1671872718683, 8149330267635,
        16287007870092.0, 1669596464541, 13547222882240.0, 1665855058725,
        1661305754913, 2705886434836, 8111060863502, 138272818285
    ]
}

# Convert to DataFrame
server_df = pd.DataFrame(server_data)
server_df['day'] = pd.to_datetime(server_df['day'])  # Convert 'day' to datetime
server_df.sort_values(by='day', inplace=True)  # Sort by day for chronological plotting

# Plot settings
plt.figure(figsize=(14, 8))
server_colors = {"hdb": "blue", "messages": "orange"}  # Color assignments for each server

for dbserver in server_df['dbserver'].unique():
    dbserver_df = server_df[server_df['dbserver'] == dbserver]
    plt.plot(dbserver_df['day'], dbserver_df['TotalHighImpactValue'], marker='o', label=dbserver, color=server_colors[dbserver])
    for i, point in dbserver_df.iterrows():
        plt.text(point['day'], point['TotalHighImpactValue'], f"{point['TotalHighImpactValue']:,.0f}", 
                 fontsize=8, rotation=45, ha='right', va='bottom', color=server_colors[dbserver])

plt.title("Server IO Load Comparison: HDB vs Messages")
plt.xlabel("Day")
plt.ylabel("Total High Impact IO Value")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    "day": [
        "2024-02-21", "2024-02-20", "2024-02-20", "2024-02-19", "2024-02-19",
        "2024-02-18", "2024-02-18", "2024-02-17", "2024-02-17", "2024-02-16",
        "2024-02-16", "2024-02-15", "2024-02-15", "2024-02-14", "2024-02-14"
    ],
    "table": [
        "users", "messages", "users", "messages", "users",
        "messages", "users", "users", "messages", "messages",
        "users", "users", "messages", "messages", "users"
    ],
    "TotalHighImpactValue": [
        6128814194901, 97439606342100.0, 153186811267947.0, 97389495205014.0, 104138394902569.0,
        97339993739146.0, 110244843171442.0, 220468632256357.0, 97307903344847.0, 97262815437860.0,
        183596131855785.0, 36702977203678.0, 97229339529514.0, 8101056055471, 110087909186747.0
    ]
}

df = pd.DataFrame(data)
df['day'] = pd.to_datetime(df['day'])  # Convert 'day' to datetime
df.sort_values(by='day', inplace=True)  # Sort by day for chronological plotting

# Plot settings
plt.figure(figsize=(14, 8))
colors = {"users": "green", "messages": "red"}  # Color assignments for each table

for table in df['table'].unique():
    table_df = df[df['table'] == table]
    plt.plot(table_df['day'], table_df['TotalHighImpactValue'], marker='o', label=table, color=colors[table])
    for i, point in table_df.iterrows():
        plt.text(point['day'], point['TotalHighImpactValue'], f"{point['TotalHighImpactValue']:,.0f}",
                 fontsize=8, rotation=45, ha='right', va='bottom', color=colors[table])

plt.title("IO Load Comparison: Users vs Messages tables")
plt.xlabel("Day")
plt.ylabel("Total High Impact IO Value")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data setup
days = [
    "2024-02-21", "2024-02-20", "2024-02-19", "2024-02-18",
    "2024-02-17", "2024-02-16", "2024-02-15", "2024-02-14"
]
users_io = [
    12257694771892, 153186811267947, 104138394902569, 110244843171442,
    220468632256357, 183596131855785, 36702977203678, 110087909186747
]
# Example total I/O for all tables (for demonstration, assuming total is 1.5x of users' I/O)
total_io = [x + x * 0.5 for x in users_io]

# Calculating I/O for other tables
other_io = [total - user for total, user in zip(total_io, users_io)]

# Creating a DataFrame
df_comparison = pd.DataFrame({
    'Day': pd.to_datetime(days),
    'Users I/O': users_io,
    'Other Tables I/O': other_io
})

# Plotting the comparison
plt.figure(figsize=(10, 6))
plt.plot(df_comparison['Day'], df_comparison['Users I/O'], label='Users Table I/O', marker='o', color='blue')
plt.plot(df_comparison['Day'], df_comparison['Other Tables I/O'], label='Other Tables I/O', marker='o', color='red')

# Adding labels and title
plt.title('I/O Comparison on HDB Server: Users Table vs Other Tables')
plt.xlabel('Date')
plt.ylabel('I/O Usage')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()
